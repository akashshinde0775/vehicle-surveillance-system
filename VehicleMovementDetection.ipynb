# %%
# Step 1: Install YOLOv8 and dependencies
# !pip install ultralytics
# !pip install opencv-python

# Importing required libraries
import ultralytics
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Vehicle Movement Detection/vehicleLPR Dataset
# Out:
# /content/drive/MyDrive/Vehicle Movement Detection/vehicleLPR Dataset

# %%
from ultralytics import YOLO
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.109 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.1/107.7 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=data.yaml epochs=33 imgsz=224 plots=True
# Out:
# Ultralytics 8.3.109 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 960, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/models/yolo/model.py", line 54, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 148, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 290, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py", line 1304, in attempt_load_one_weight
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=data/test/images
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 960, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/models/yolo/model.py", line 54, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 148, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 290, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py", line 1304, in attempt_load_one_weight
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('runs/detect/predict/*.jpg')[:3]:
    display(Image(filename=image_path, width=600))
    print("\n")
